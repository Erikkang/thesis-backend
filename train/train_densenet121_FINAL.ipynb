# %% [markdown]
# # DenseNet-121 Training Notebook
# ## Phase 1: Initial Training (Frozen Backbone)
# ## Phase 2: Fine-tuning (Unfrozen Layers)

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # CELL 1: IMPORTS AND CONFIGURATION

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns

print("✓ All libraries imported successfully!")
print(f"TensorFlow version: {tf.__version__}")

# Configuration
DATASET_PATH = r"D:\Datasets\skin_dataset\Skin_Conditions"
IMAGE_SIZE = 224
BATCH_SIZE = 32
INITIAL_EPOCHS = 30
FINETUNING_EPOCHS = 25
INITIAL_LR = 0.001
FINETUNING_LR = 0.0001
CLASS_NAMES = ['acne', 'eczema', 'keratosis', 'carcinoma', 'milia', 'rosacea']
NUM_CLASSES = len(CLASS_NAMES)

print(f"✓ Configuration set: Image Size={IMAGE_SIZE}, Batch Size={BATCH_SIZE}, Classes={NUM_CLASSES}")
# Out:
# ✓ All libraries imported successfully!
# TensorFlow version: 2.13.0
# ✓ Configuration set: Image Size=224, Batch Size=32, Classes=6

# %% [markdown]
# # CELL 2: LOAD DATASET

# %%
def load_images_from_folder(dataset_path):
    """Load images and labels from folder structure"""
    images = []
    labels = []
    
    for class_idx, class_name in enumerate(CLASS_NAMES):
        class_path = os.path.join(dataset_path, class_name)
        if not os.path.exists(class_path):
            print(f"❌ ERROR: Class folder '{class_name}' not found at {class_path}")
            continue
            
        class_images = 0
        for img_file in os.listdir(class_path):
            if img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(class_path, img_file)
                try:
                    img = keras.preprocessing.image.load_img(img_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
                    img_array = keras.preprocessing.image.img_to_array(img)
                    images.append(img_array)
                    labels.append(class_idx)
                    class_images += 1
                except Exception as e:
                    print(f"⚠ Warning - Error loading {img_path}: {e}")
        
        print(f"  • {class_name}: {class_images} images loaded")
    
    return np.array(images), np.array(labels)

print("\n📂 Loading dataset...")
print(f"Dataset path: {DATASET_PATH}\n")

X, y = load_images_from_folder(DATASET_PATH)

print(f"\n✓ Dataset loaded successfully!")
print(f"  • Total images: {X.shape[0]}")
print(f"  • Image shape: {X.shape[1:]}")
print(f"  • Number of classes: {NUM_CLASSES}")
print(f"  • Class distribution: {np.bincount(y)}")
# Out:
# 📂 Loading dataset...
# Dataset path: D:\Datasets\skin_dataset\Skin_Conditions
#
#   • acne: 399 images loaded
#   • eczema: 399 images loaded
#   • keratosis: 399 images loaded
#   • carcinoma: 399 images loaded
#   • milia: 399 images loaded
#   • rosacea: 399 images loaded
#
# ✓ Dataset loaded successfully!
#   • Total images: 2394
#   • Image shape: (224, 224, 3)
#   • Number of classes: 6
#   • Class distribution: [399 399 399 399 399 399]

# %% [markdown]
# # CELL 3: PREPROCESSING & DATA SPLIT

# %%
print("\n🔄 Preprocessing data...")

# DenseNet121 specific preprocessing: normalize to [0, 1] range
X = X / 255.0
print("  ✓ Images normalized to [0, 1] range")

# Convert labels to one-hot encoding
y_encoded = keras.utils.to_categorical(y, NUM_CLASSES)
print("  ✓ Labels converted to one-hot encoding")

# Split dataset: 80% training, 20% validation
X_train, X_val, y_train, y_val = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y
)

print(f"\n  ✓ Dataset split completed:")
print(f"    - Training set: {X_train.shape[0]} images ({X_train.shape[0]/X.shape[0]*100:.1f}%)")
print(f"    - Validation set: {X_val.shape[0]} images ({X_val.shape[0]/X.shape[0]*100:.1f}%)")

# Calculate class weights for imbalanced dataset
class_counts = np.bincount(y)
class_weights = {i: X.shape[0] / (NUM_CLASSES * count) for i, count in enumerate(class_counts)}
print(f"\n  ✓ Class weights calculated (for imbalanced data handling):")
for class_name, weight in zip(CLASS_NAMES, class_weights.values()):
    print(f"    - {class_name}: {weight:.4f}")

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    shear_range=0.15,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator()  # No augmentation for validation

print(f"\n  ✓ Data augmentation configured (training set only)")
print(f"✓ Preprocessing complete!")
# Out:
# 🔄 Preprocessing data...
#   ✓ Images normalized to [0, 1] range
#   ✓ Labels converted to one-hot encoding
#
#   ✓ Dataset split completed:
#     - Training set: 1915 images (80.0%)
#     - Validation set: 479 images (20.0%)
#
#   ✓ Class weights calculated (for imbalanced data handling):
#     - acne: 1.0000
#     - eczema: 1.0000
#     - keratosis: 1.0000
#     - carcinoma: 1.0000
#     - milia: 1.0000
#     - rosacea: 1.0000
#
#   ✓ Data augmentation configured (training set only)
# ✓ Preprocessing complete!

# %% [markdown]
# # CELL 4: BUILD DENSENET121 MODEL

# %%
print("\n🏗️ Building DenseNet121 model architecture...")

# Load pretrained DenseNet121 - ONLY the base model
base_model = DenseNet121(
    weights='imagenet',
    include_top=False,
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
)

print("  ✓ DenseNet121 base model loaded (ImageNet pretrained weights)")

# Freeze base model layers initially for Phase 1
base_model.trainable = False
print("  ✓ DenseNet121 layers FROZEN for Phase 1")

# Build model: Input → DenseNet121 layers → Output layer ONLY
model = keras.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

print("\n  ✓ Model architecture:")
print("    INPUT (224x224x3)")
print("    ↓")
print("    DenseNet121 (pretrained ImageNet weights)")
print("    ↓")
print("    GlobalAveragePooling2D")
print("    ↓")
print(f"    OUTPUT: Dense({NUM_CLASSES}, softmax)")

print(f"\n📝 PURE DenseNet-121 ONLY - High Accuracy Architecture")
print(f"   ~8M parameters, excellent for skin condition classification")

print(f"\n✓ Model built successfully!")
print(f"Total parameters: {model.count_params():,}")

model.summary()
# Out:
# 🏗️ Building DenseNet121 model architecture...
#   ✓ DenseNet121 base model loaded (ImageNet pretrained weights)
#   ✓ DenseNet121 layers FROZEN for Phase 1
#
#   ✓ Model architecture:
#     INPUT (224x224x3)
#     ↓
#     DenseNet121 (pretrained ImageNet weights)
#     ↓
#     GlobalAveragePooling2D
#     ↓
#     OUTPUT: Dense(6, softmax)
#
# 📝 PURE DenseNet-121 ONLY - High Accuracy Architecture
#    ~8M parameters, excellent for skin condition classification
#
# ✓ Model built successfully!
# Total parameters: 7,043,654
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 6)                 6150
#
# =================================================================
# Total params: 7043654 (26.87 MB)
# Trainable params: 6150 (24.02 KB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________

# %% [markdown]
# # CELL 5: PHASE 1 - INITIAL TRAINING (FROZEN BACKBONE)

# %%
print("\n" + "="*70)
print("PHASE 1: INITIAL TRAINING (FROZEN BACKBONE)")
print("="*70)

print("\n⚙️ Compiling model...")
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=INITIAL_LR),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        'accuracy',
        keras.metrics.TopKCategoricalAccuracy(k=3, name='top_3_accuracy'),
        keras.metrics.Precision(),
        keras.metrics.Recall()
    ]
)
print("✓ Model compiled with:")
print(f"  - Optimizer: Adam (LR={INITIAL_LR})")
print(f"  - Loss: Categorical Cross-Entropy (label_smoothing=0.1)")
print(f"  - Metrics: Accuracy, Top-3 Accuracy, Precision, Recall")

# Define callbacks - MONITORING ACCURACY
initial_callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1,
        mode='max'
    ),
    ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1,
        mode='max'
    ),
    ModelCheckpoint(
        'best_model_phase1_densenet.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1,
        mode='max'
    )
]

print(f"\n📋 Callbacks configured:")
print(f"  - EarlyStopping (monitors: val_accuracy, patience=15 epochs)")
print(f"  - ReduceLROnPlateau (monitors: val_accuracy, factor=0.5, patience=5 epochs)")
print(f"  - ModelCheckpoint (monitors: val_accuracy, saves best model)")

print(f"\n🚀 Starting Phase 1 Training...")
print(f"   Epochs: {INITIAL_EPOCHS} | Batch Size: {BATCH_SIZE}")
print(f"   Training samples: {X_train.shape[0]}")
print(f"   Validation samples: {X_val.shape[0]}")

history_phase1 = model.fit(
    X_train, y_train,
    epochs=INITIAL_EPOCHS,
    validation_data=(X_val, y_val),
    batch_size=BATCH_SIZE,
    class_weight=class_weights,
    callbacks=initial_callbacks,
    verbose=1
)

print("\n✓ Phase 1 Training completed!")
# Out:
# ======================================================================
# PHASE 1: INITIAL TRAINING (FROZEN BACKBONE)
# ======================================================================
#
# ⚙️ Compiling model...
# ✓ Model compiled with:
#   - Optimizer: Adam (LR=0.001)
#   - Loss: Categorical Cross-Entropy (label_smoothing=0.1)
#   - Metrics: Accuracy, Top-3 Accuracy, Precision, Recall
#
# 📋 Callbacks configured:
#   - EarlyStopping (monitors: val_accuracy, patience=15 epochs)
#   - ReduceLROnPlateau (monitors: val_accuracy, factor=0.5, patience=5 epochs)
#   - ModelCheckpoint (monitors: val_accuracy, saves best model)
#
# 🚀 Starting Phase 1 Training...
#    Epochs: 30 | Batch Size: 32
#    Training samples: 1915
#    Validation samples: 479
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 1.5395 - accuracy: 0.4590 - top_3_accuracy: 0.7561 - precision: 0.7312 - recall: 0.1775
# Epoch 1: val_accuracy improved from -inf to 0.66806, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 127s 2s/step - loss: 1.5395 - accuracy: 0.4590 - top_3_accuracy: 0.7561 - precision: 0.7312 - recall: 0.1775 - val_loss: 1.1747 - val_accuracy: 0.6681 - val_top_3_accuracy: 0.8956 - val_precision: 0.8918 - val_recall: 0.3612 - lr: 0.0010
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 1.0597 - accuracy: 0.7060 - top_3_accuracy: 0.9316 - precision: 0.9221 - recall: 0.4695
# Epoch 2: val_accuracy improved from 0.66806 to 0.73278, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 111s 2s/step - loss: 1.0597 - accuracy: 0.7060 - top_3_accuracy: 0.9316 - precision: 0.9221 - recall: 0.4695 - val_loss: 1.0071 - val_accuracy: 0.7328 - val_top_3_accuracy: 0.9478 - val_precision: 0.8900 - val_recall: 0.5407 - lr: 0.0010
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 0.9367 - accuracy: 0.7749 - top_3_accuracy: 0.9535 - precision: 0.9296 - recall: 0.5796
# Epoch 3: val_accuracy improved from 0.73278 to 0.75574, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 110s 2s/step - loss: 0.9367 - accuracy: 0.7749 - top_3_accuracy: 0.9535 - precision: 0.9296 - recall: 0.5796 - val_loss: 0.9250 - val_accuracy: 0.7557 - val_top_3_accuracy: 0.9541 - val_precision: 0.9097 - val_recall: 0.6096 - lr: 0.0010
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 0.8702 - accuracy: 0.8031 - top_3_accuracy: 0.9655 - precision: 0.9383 - recall: 0.6355
# Epoch 4: val_accuracy improved from 0.75574 to 0.80585, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 109s 2s/step - loss: 0.8702 - accuracy: 0.8031 - top_3_accuracy: 0.9655 - precision: 0.9383 - recall: 0.6355 - val_loss: 0.8742 - val_accuracy: 0.8058 - val_top_3_accuracy: 0.9645 - val_precision: 0.9083 - val_recall: 0.6409 - lr: 0.0010
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 0.8239 - accuracy: 0.8261 - top_3_accuracy: 0.9713 - precision: 0.9448 - recall: 0.6883
# Epoch 5: val_accuracy improved from 0.80585 to 0.81628, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 110s 2s/step - loss: 0.8239 - accuracy: 0.8261 - top_3_accuracy: 0.9713 - precision: 0.9448 - recall: 0.6883 - val_loss: 0.8495 - val_accuracy: 0.8163 - val_top_3_accuracy: 0.9729 - val_precision: 0.8997 - val_recall: 0.6555 - lr: 0.0010
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7920 - accuracy: 0.8522 - top_3_accuracy: 0.9786 - precision: 0.9477 - recall: 0.7196
# Epoch 6: val_accuracy improved from 0.81628 to 0.82881, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 108s 2s/step - loss: 0.7920 - accuracy: 0.8522 - top_3_accuracy: 0.9786 - precision: 0.9477 - recall: 0.7196 - val_loss: 0.8235 - val_accuracy: 0.8288 - val_top_3_accuracy: 0.9729 - val_precision: 0.9160 - val_recall: 0.7056 - lr: 0.0010
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7711 - accuracy: 0.8512 - top_3_accuracy: 0.9796 - precision: 0.9610 - recall: 0.7342
# Epoch 7: val_accuracy improved from 0.82881 to 0.84134, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.7711 - accuracy: 0.8512 - top_3_accuracy: 0.9796 - precision: 0.9610 - recall: 0.7342 - val_loss: 0.8034 - val_accuracy: 0.8413 - val_top_3_accuracy: 0.9770 - val_precision: 0.9299 - val_recall: 0.7203 - lr: 0.0010
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7550 - accuracy: 0.8668 - top_3_accuracy: 0.9859 - precision: 0.9553 - recall: 0.7478
# Epoch 8: val_accuracy did not improve from 0.84134
# 60/60 [==============================] - 107s 2s/step - loss: 0.7550 - accuracy: 0.8668 - top_3_accuracy: 0.9859 - precision: 0.9553 - recall: 0.7478 - val_loss: 0.8025 - val_accuracy: 0.8330 - val_top_3_accuracy: 0.9833 - val_precision: 0.9276 - val_recall: 0.7223 - lr: 0.0010
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7356 - accuracy: 0.8773 - top_3_accuracy: 0.9864 - precision: 0.9566 - recall: 0.7713
# Epoch 9: val_accuracy did not improve from 0.84134
# 60/60 [==============================] - 107s 2s/step - loss: 0.7356 - accuracy: 0.8773 - top_3_accuracy: 0.9864 - precision: 0.9566 - recall: 0.7713 - val_loss: 0.7875 - val_accuracy: 0.8413 - val_top_3_accuracy: 0.9854 - val_precision: 0.9261 - val_recall: 0.7328 - lr: 0.0010
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7213 - accuracy: 0.8841 - top_3_accuracy: 0.9885 - precision: 0.9617 - recall: 0.7859
# Epoch 10: val_accuracy improved from 0.84134 to 0.85595, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 108s 2s/step - loss: 0.7213 - accuracy: 0.8841 - top_3_accuracy: 0.9885 - precision: 0.9617 - recall: 0.7859 - val_loss: 0.7734 - val_accuracy: 0.8559 - val_top_3_accuracy: 0.9875 - val_precision: 0.9271 - val_recall: 0.7432 - lr: 0.0010
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.8966 - top_3_accuracy: 0.9885 - precision: 0.9651 - recall: 0.7937
# Epoch 11: val_accuracy improved from 0.85595 to 0.86639, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.7120 - accuracy: 0.8966 - top_3_accuracy: 0.9885 - precision: 0.9651 - recall: 0.7937 - val_loss: 0.7612 - val_accuracy: 0.8664 - val_top_3_accuracy: 0.9875 - val_precision: 0.9381 - val_recall: 0.7599 - lr: 0.0010
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 0.7007 - accuracy: 0.8977 - top_3_accuracy: 0.9896 - precision: 0.9722 - recall: 0.8042
# Epoch 12: val_accuracy did not improve from 0.86639
# 60/60 [==============================] - 107s 2s/step - loss: 0.7007 - accuracy: 0.8977 - top_3_accuracy: 0.9896 - precision: 0.9722 - recall: 0.8042 - val_loss: 0.7633 - val_accuracy: 0.8622 - val_top_3_accuracy: 0.9875 - val_precision: 0.9304 - val_recall: 0.7537 - lr: 0.0010
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.9055 - top_3_accuracy: 0.9948 - precision: 0.9730 - recall: 0.8099
# Epoch 13: val_accuracy improved from 0.86639 to 0.87265, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.6903 - accuracy: 0.9055 - top_3_accuracy: 0.9948 - precision: 0.9730 - recall: 0.8099 - val_loss: 0.7548 - val_accuracy: 0.8727 - val_top_3_accuracy: 0.9916 - val_precision: 0.9335 - val_recall: 0.7620 - lr: 0.0010
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.9123 - top_3_accuracy: 0.9953 - precision: 0.9709 - recall: 0.8198
# Epoch 14: val_accuracy did not improve from 0.87265
# 60/60 [==============================] - 106s 2s/step - loss: 0.6819 - accuracy: 0.9123 - top_3_accuracy: 0.9953 - precision: 0.9709 - recall: 0.8198 - val_loss: 0.7529 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9896 - val_precision: 0.9352 - val_recall: 0.7537 - lr: 0.0010
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.9159 - top_3_accuracy: 0.9953 - precision: 0.9717 - recall: 0.8261
# Epoch 15: val_accuracy improved from 0.87265 to 0.87474, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.6743 - accuracy: 0.9159 - top_3_accuracy: 0.9953 - precision: 0.9717 - recall: 0.8261 - val_loss: 0.7448 - val_accuracy: 0.8747 - val_top_3_accuracy: 0.9896 - val_precision: 0.9365 - val_recall: 0.7704 - lr: 0.0010
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6705 - accuracy: 0.9164 - top_3_accuracy: 0.9958 - precision: 0.9713 - recall: 0.8308
# Epoch 16: val_accuracy improved from 0.87474 to 0.88518, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.6705 - accuracy: 0.9164 - top_3_accuracy: 0.9958 - precision: 0.9713 - recall: 0.8308 - val_loss: 0.7402 - val_accuracy: 0.8852 - val_top_3_accuracy: 0.9916 - val_precision: 0.9345 - val_recall: 0.7745 - lr: 0.0010
# Epoch 17/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.9222 - top_3_accuracy: 0.9948 - precision: 0.9769 - recall: 0.8397
# Epoch 17: val_accuracy did not improve from 0.88518
# 60/60 [==============================] - 106s 2s/step - loss: 0.6595 - accuracy: 0.9222 - top_3_accuracy: 0.9948 - precision: 0.9769 - recall: 0.8397 - val_loss: 0.7699 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9854 - val_precision: 0.9259 - val_recall: 0.7829 - lr: 0.0010
# Epoch 18/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6550 - accuracy: 0.9253 - top_3_accuracy: 0.9958 - precision: 0.9765 - recall: 0.8460
# Epoch 18: val_accuracy did not improve from 0.88518
# 60/60 [==============================] - 107s 2s/step - loss: 0.6550 - accuracy: 0.9253 - top_3_accuracy: 0.9958 - precision: 0.9765 - recall: 0.8460 - val_loss: 0.7355 - val_accuracy: 0.8789 - val_top_3_accuracy: 0.9916 - val_precision: 0.9327 - val_recall: 0.7808 - lr: 0.0010
# Epoch 19/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6518 - accuracy: 0.9316 - top_3_accuracy: 0.9963 - precision: 0.9789 - recall: 0.8491
# Epoch 19: val_accuracy did not improve from 0.88518
# 60/60 [==============================] - 107s 2s/step - loss: 0.6518 - accuracy: 0.9316 - top_3_accuracy: 0.9963 - precision: 0.9789 - recall: 0.8491 - val_loss: 0.7395 - val_accuracy: 0.8789 - val_top_3_accuracy: 0.9896 - val_precision: 0.9291 - val_recall: 0.7933 - lr: 0.0010
# Epoch 20/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6453 - accuracy: 0.9342 - top_3_accuracy: 0.9979 - precision: 0.9767 - recall: 0.8533
# Epoch 20: val_accuracy improved from 0.88518 to 0.89770, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.6453 - accuracy: 0.9342 - top_3_accuracy: 0.9979 - precision: 0.9767 - recall: 0.8533 - val_loss: 0.7232 - val_accuracy: 0.8977 - val_top_3_accuracy: 0.9896 - val_precision: 0.9325 - val_recall: 0.8079 - lr: 0.0010
# Epoch 21/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.9352 - top_3_accuracy: 0.9979 - precision: 0.9810 - recall: 0.8606
# Epoch 21: val_accuracy did not improve from 0.89770
# 60/60 [==============================] - 107s 2s/step - loss: 0.6400 - accuracy: 0.9352 - top_3_accuracy: 0.9979 - precision: 0.9810 - recall: 0.8606 - val_loss: 0.7285 - val_accuracy: 0.8852 - val_top_3_accuracy: 0.9916 - val_precision: 0.9366 - val_recall: 0.8017 - lr: 0.0010
# Epoch 22/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6343 - accuracy: 0.9410 - top_3_accuracy: 0.9984 - precision: 0.9834 - recall: 0.8637
# Epoch 22: val_accuracy improved from 0.89770 to 0.90188, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.6343 - accuracy: 0.9410 - top_3_accuracy: 0.9984 - precision: 0.9834 - recall: 0.8637 - val_loss: 0.7223 - val_accuracy: 0.9019 - val_top_3_accuracy: 0.9875 - val_precision: 0.9369 - val_recall: 0.8058 - lr: 0.0010
# Epoch 23/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.9363 - top_3_accuracy: 0.9974 - precision: 0.9800 - recall: 0.8700
# Epoch 23: val_accuracy did not improve from 0.90188
# 60/60 [==============================] - 106s 2s/step - loss: 0.6307 - accuracy: 0.9363 - top_3_accuracy: 0.9974 - precision: 0.9800 - recall: 0.8700 - val_loss: 0.7318 - val_accuracy: 0.8831 - val_top_3_accuracy: 0.9937 - val_precision: 0.9337 - val_recall: 0.7933 - lr: 0.0010
# Epoch 24/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6281 - accuracy: 0.9431 - top_3_accuracy: 0.9974 - precision: 0.9828 - recall: 0.8642
# Epoch 24: val_accuracy did not improve from 0.90188
# 60/60 [==============================] - 107s 2s/step - loss: 0.6281 - accuracy: 0.9431 - top_3_accuracy: 0.9974 - precision: 0.9828 - recall: 0.8642 - val_loss: 0.7273 - val_accuracy: 0.8768 - val_top_3_accuracy: 0.9896 - val_precision: 0.9314 - val_recall: 0.7933 - lr: 0.0010
# Epoch 25/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6202 - accuracy: 0.9446 - top_3_accuracy: 0.9974 - precision: 0.9853 - recall: 0.8747
# Epoch 25: val_accuracy improved from 0.90188 to 0.90814, saving model to best_model_phase1_densenet.h5
# 60/60 [==============================] - 107s 2s/step - loss: 0.6202 - accuracy: 0.9446 - top_3_accuracy: 0.9974 - precision: 0.9853 - recall: 0.8747 - val_loss: 0.7187 - val_accuracy: 0.9081 - val_top_3_accuracy: 0.9875 - val_precision: 0.9356 - val_recall: 0.8184 - lr: 0.0010
# Epoch 26/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6232 - accuracy: 0.9426 - top_3_accuracy: 0.9995 - precision: 0.9825 - recall: 0.8778
# Epoch 26: val_accuracy did not improve from 0.90814
# 60/60 [==============================] - 106s 2s/step - loss: 0.6232 - accuracy: 0.9426 - top_3_accuracy: 0.9995 - precision: 0.9825 - recall: 0.8778 - val_loss: 0.7353 - val_accuracy: 0.8768 - val_top_3_accuracy: 0.9916 - val_precision: 0.9287 - val_recall: 0.7891 - lr: 0.0010
# Epoch 27/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6144 - accuracy: 0.9493 - top_3_accuracy: 0.9979 - precision: 0.9842 - recall: 0.8768
# Epoch 27: val_accuracy did not improve from 0.90814
# 60/60 [==============================] - 107s 2s/step - loss: 0.6144 - accuracy: 0.9493 - top_3_accuracy: 0.9979 - precision: 0.9842 - recall: 0.8768 - val_loss: 0.7199 - val_accuracy: 0.8831 - val_top_3_accuracy: 0.9916 - val_precision: 0.9303 - val_recall: 0.8079 - lr: 0.0010
# Epoch 28/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6119 - accuracy: 0.9493 - top_3_accuracy: 0.9979 - precision: 0.9860 - recall: 0.8846
# Epoch 28: val_accuracy did not improve from 0.90814
# 60/60 [==============================] - 108s 2s/step - loss: 0.6119 - accuracy: 0.9493 - top_3_accuracy: 0.9979 - precision: 0.9860 - recall: 0.8846 - val_loss: 0.7164 - val_accuracy: 0.9040 - val_top_3_accuracy: 0.9896 - val_precision: 0.9311 - val_recall: 0.8184 - lr: 0.0010
# Epoch 29/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6127 - accuracy: 0.9504 - top_3_accuracy: 0.9969 - precision: 0.9832 - recall: 0.8841
# Epoch 29: val_accuracy did not improve from 0.90814
# 60/60 [==============================] - 107s 2s/step - loss: 0.6127 - accuracy: 0.9504 - top_3_accuracy: 0.9969 - precision: 0.9832 - recall: 0.8841 - val_loss: 0.7176 - val_accuracy: 0.9040 - val_top_3_accuracy: 0.9896 - val_precision: 0.9359 - val_recall: 0.8225 - lr: 0.0010
# Epoch 30/30
# 60/60 [==============================] - ETA: 0s - loss: 0.6046 - accuracy: 0.9556 - top_3_accuracy: 0.9984 - precision: 0.9890 - recall: 0.8930
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 30: val_accuracy did not improve from 0.90814
# 60/60 [==============================] - 111s 2s/step - loss: 0.6046 - accuracy: 0.9556 - top_3_accuracy: 0.9984 - precision: 0.9890 - recall: 0.8930 - val_loss: 0.7296 - val_accuracy: 0.8789 - val_top_3_accuracy: 0.9937 - val_precision: 0.9260 - val_recall: 0.8100 - lr: 0.0010
#
# ✓ Phase 1 Training completed!

# %% [markdown]
# # CELL 6: PHASE 2 - FINE-TUNING (PARTIAL UNFREEZING)

# %%
print("\n" + "="*70)
print("PHASE 2: FINE-TUNING (PARTIAL UNFREEZING)")
print("="*70)

print("\n🔓 Unfreezing last 50 layers of DenseNet121...")

# Unfreeze last 50 layers
unfrozen_count = 0
for layer in base_model.layers[-50:]:
    layer.trainable = True
    unfrozen_count += 1

print(f"✓ {unfrozen_count} layers unfrozen for fine-tuning")

# Recompile with lower learning rate
print("\n⚙️ Recompiling model with lower learning rate...")
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=FINETUNING_LR),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        'accuracy',
        keras.metrics.TopKCategoricalAccuracy(k=3, name='top_3_accuracy'),
        keras.metrics.Precision(),
        keras.metrics.Recall()
    ]
)

print("✓ Model recompiled with:")
print(f"  - Optimizer: Adam (LR={FINETUNING_LR})")
print(f"  - Loss: Categorical Cross-Entropy (label_smoothing=0.1)")
print(f"  - Metrics: Accuracy, Top-3 Accuracy, Precision, Recall")

# Fine-tuning callbacks - MONITORING ACCURACY
finetuning_callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=12,
        restore_best_weights=True,
        verbose=1,
        mode='max'
    ),
    ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=4,
        min_lr=1e-8,
        verbose=1,
        mode='max'
    ),
    ModelCheckpoint(
        'best_model_phase2_densenet.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1,
        mode='max'
    )
]

print(f"\n📋 Callbacks configured:")
print(f"  - EarlyStopping (monitors: val_accuracy, patience=12 epochs)")
print(f"  - ReduceLROnPlateau (monitors: val_accuracy, factor=0.5, patience=4 epochs)")
print(f"  - ModelCheckpoint (monitors: val_accuracy, saves best model)")

print(f"\n🚀 Starting Phase 2 Fine-Tuning...")
print(f"   Epochs: {FINETUNING_EPOCHS} | Batch Size: {BATCH_SIZE}")

history_phase2 = model.fit(
    X_train, y_train,
    epochs=FINETUNING_EPOCHS,
    validation_data=(X_val, y_val),
    batch_size=BATCH_SIZE,
    class_weight=class_weights,
    callbacks=finetuning_callbacks,
    verbose=1
)

print("\n✓ Phase 2 Fine-Tuning completed!")
# Out:
# ======================================================================
# PHASE 2: FINE-TUNING (PARTIAL UNFREEZING)
# ======================================================================
#
# 🔓 Unfreezing last 50 layers of DenseNet121...
# ✓ 50 layers unfrozen for fine-tuning
#
# ⚙️ Recompiling model with lower learning rate...
# ✓ Model recompiled with:
#   - Optimizer: Adam (LR=0.0001)
#   - Loss: Categorical Cross-Entropy (label_smoothing=0.1)
#   - Metrics: Accuracy, Top-3 Accuracy, Precision, Recall
#
# 📋 Callbacks configured:
#   - EarlyStopping (monitors: val_accuracy, patience=12 epochs)
#   - ReduceLROnPlateau (monitors: val_accuracy, factor=0.5, patience=4 epochs)
#   - ModelCheckpoint (monitors: val_accuracy, saves best model)
#
# 🚀 Starting Phase 2 Fine-Tuning...
#    Epochs: 25 | Batch Size: 32
# Epoch 1/25
# 60/60 [==============================] - ETA: 0s - loss: 0.7853 - accuracy: 0.8668 - top_3_accuracy: 0.9775 - precision_1: 0.9273 - recall_1: 0.8063
# Epoch 1: val_accuracy improved from -inf to 0.87683, saving model to best_model_phase2_densenet.h5
# 60/60 [==============================] - 114s 2s/step - loss: 0.7853 - accuracy: 0.8668 - top_3_accuracy: 0.9775 - precision_1: 0.9273 - recall_1: 0.8063 - val_loss: 0.7744 - val_accuracy: 0.8768 - val_top_3_accuracy: 0.9896 - val_precision_1: 0.9135 - val_recall_1: 0.7933 - lr: 1.0000e-04
# Epoch 2/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.9102 - top_3_accuracy: 0.9937 - precision_1: 0.9494 - recall_1: 0.8533
# Epoch 2: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 112s 2s/step - loss: 0.6953 - accuracy: 0.9102 - top_3_accuracy: 0.9937 - precision_1: 0.9494 - recall_1: 0.8533 - val_loss: 0.7832 - val_accuracy: 0.8727 - val_top_3_accuracy: 0.9875 - val_precision_1: 0.8956 - val_recall_1: 0.8058 - lr: 1.0000e-04
# Epoch 3/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.9196 - top_3_accuracy: 0.9948 - precision_1: 0.9563 - recall_1: 0.8569
# Epoch 3: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 133s 2s/step - loss: 0.6894 - accuracy: 0.9196 - top_3_accuracy: 0.9948 - precision_1: 0.9563 - recall_1: 0.8569 - val_loss: 0.7912 - val_accuracy: 0.8664 - val_top_3_accuracy: 0.9833 - val_precision_1: 0.8947 - val_recall_1: 0.8163 - lr: 1.0000e-04
# Epoch 4/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6845 - accuracy: 0.9191 - top_3_accuracy: 0.9932 - precision_1: 0.9546 - recall_1: 0.8674
# Epoch 4: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 131s 2s/step - loss: 0.6845 - accuracy: 0.9191 - top_3_accuracy: 0.9932 - precision_1: 0.9546 - recall_1: 0.8674 - val_loss: 0.8061 - val_accuracy: 0.8664 - val_top_3_accuracy: 0.9896 - val_precision_1: 0.8919 - val_recall_1: 0.8267 - lr: 1.0000e-04
# Epoch 5/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.9243 - top_3_accuracy: 0.9963 - precision_1: 0.9630 - recall_1: 0.8700
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 5: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 130s 2s/step - loss: 0.6751 - accuracy: 0.9243 - top_3_accuracy: 0.9963 - precision_1: 0.9630 - recall_1: 0.8700 - val_loss: 0.8116 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9875 - val_precision_1: 0.8964 - val_recall_1: 0.8309 - lr: 1.0000e-04
# Epoch 6/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6863 - accuracy: 0.9191 - top_3_accuracy: 0.9937 - precision_1: 0.9559 - recall_1: 0.8601
# Epoch 6: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 127s 2s/step - loss: 0.6863 - accuracy: 0.9191 - top_3_accuracy: 0.9937 - precision_1: 0.9559 - recall_1: 0.8601 - val_loss: 0.8160 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9812 - val_precision_1: 0.8916 - val_recall_1: 0.8246 - lr: 5.0000e-05
# Epoch 7/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6850 - accuracy: 0.9164 - top_3_accuracy: 0.9943 - precision_1: 0.9595 - recall_1: 0.8658
# Epoch 7: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 117s 2s/step - loss: 0.6850 - accuracy: 0.9164 - top_3_accuracy: 0.9943 - precision_1: 0.9595 - recall_1: 0.8658 - val_loss: 0.8198 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9791 - val_precision_1: 0.8957 - val_recall_1: 0.8246 - lr: 5.0000e-05
# Epoch 8/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.9248 - top_3_accuracy: 0.9953 - precision_1: 0.9588 - recall_1: 0.8747
# Epoch 8: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 117s 2s/step - loss: 0.6718 - accuracy: 0.9248 - top_3_accuracy: 0.9953 - precision_1: 0.9588 - recall_1: 0.8747 - val_loss: 0.8196 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9812 - val_precision_1: 0.8916 - val_recall_1: 0.8246 - lr: 5.0000e-05
# Epoch 9/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.9279 - top_3_accuracy: 0.9937 - precision_1: 0.9660 - recall_1: 0.8762
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 9: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 117s 2s/step - loss: 0.6701 - accuracy: 0.9279 - top_3_accuracy: 0.9937 - precision_1: 0.9660 - recall_1: 0.8762 - val_loss: 0.8203 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9812 - val_precision_1: 0.8957 - val_recall_1: 0.8246 - lr: 5.0000e-05
# Epoch 10/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6679 - accuracy: 0.9295 - top_3_accuracy: 0.9958 - precision_1: 0.9586 - recall_1: 0.8715
# Epoch 10: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 117s 2s/step - loss: 0.6679 - accuracy: 0.9295 - top_3_accuracy: 0.9958 - precision_1: 0.9586 - recall_1: 0.8715 - val_loss: 0.8207 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9791 - val_precision_1: 0.8937 - val_recall_1: 0.8246 - lr: 2.5000e-05
# Epoch 11/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6650 - accuracy: 0.9279 - top_3_accuracy: 0.9969 - precision_1: 0.9661 - recall_1: 0.8783
# Epoch 11: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 117s 2s/step - loss: 0.6650 - accuracy: 0.9279 - top_3_accuracy: 0.9969 - precision_1: 0.9661 - recall_1: 0.8783 - val_loss: 0.8196 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9791 - val_precision_1: 0.8934 - val_recall_1: 0.8225 - lr: 2.5000e-05
# Epoch 12/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.9243 - top_3_accuracy: 0.9958 - precision_1: 0.9638 - recall_1: 0.8757
# Epoch 12: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 118s 2s/step - loss: 0.6713 - accuracy: 0.9243 - top_3_accuracy: 0.9958 - precision_1: 0.9638 - recall_1: 0.8757 - val_loss: 0.8196 - val_accuracy: 0.8685 - val_top_3_accuracy: 0.9791 - val_precision_1: 0.8934 - val_recall_1: 0.8225 - lr: 2.5000e-05
# Epoch 13/25
# 60/60 [==============================] - ETA: 0s - loss: 0.6729 - accuracy: 0.9232 - top_3_accuracy: 0.9943 - precision_1: 0.9601 - recall_1: 0.8674Restoring model weights from the end of the best epoch: 1.
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 13: val_accuracy did not improve from 0.87683
# 60/60 [==============================] - 122s 2s/step - loss: 0.6729 - accuracy: 0.9232 - top_3_accuracy: 0.9943 - precision_1: 0.9601 - recall_1: 0.8674 - val_loss: 0.8199 - val_accuracy: 0.8747 - val_top_3_accuracy: 0.9791 - val_precision_1: 0.8914 - val_recall_1: 0.8225 - lr: 2.5000e-05
# Epoch 13: early stopping
#
# ✓ Phase 2 Fine-Tuning completed!

# %% [markdown]
# # CELL 7: MODEL EVALUATION & METRICS

# %%
print("\n" + "="*70)
print("MODEL EVALUATION")
print("="*70)

print("\n📊 Evaluating model on validation set...")

val_results = model.evaluate(X_val, y_val, verbose=0)
val_loss = val_results[0]
val_accuracy = val_results[1]
val_top3 = val_results[2]
val_precision = val_results[3]
val_recall = val_results[4]

print(f"\n✓ Validation Results:")
print(f"  - Loss: {val_loss:.4f}")
print(f"  - Accuracy: {val_accuracy:.4f} ({val_accuracy*100:.2f}%)")
print(f"  - Top-3 Accuracy: {val_top3:.4f} ({val_top3*100:.2f}%)")
print(f"  - Precision: {val_precision:.4f}")
print(f"  - Recall: {val_recall:.4f}")

# Calculate F1-score
f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)
print(f"  - F1-Score: {f1_score:.4f}")

# Save final model
print("\n💾 Saving final model...")
model.save('final_densenet121_model.h5')
print("✓ Final model saved as 'final_densenet121_model.h5'")
# Out:
# ======================================================================
# MODEL EVALUATION
# ======================================================================
#
# 📊 Evaluating model on validation set...
#
# ✓ Validation Results:
#   - Loss: 0.7744
#   - Accuracy: 0.8768 (87.68%)
#   - Top-3 Accuracy: 0.9896 (98.96%)
#   - Precision: 0.9135
#   - Recall: 0.7933
#   - F1-Score: 0.8492
#
# 💾 Saving final model...
# ✓ Final model saved as 'final_densenet121_model.h5'

# %% [markdown]
# # CELL 8: CONFUSION MATRIX & CLASSIFICATION REPORT

# %%
print("\n" + "="*70)
print("CONFUSION MATRIX & CLASSIFICATION REPORT")
print("="*70)

print("\n🔍 Generating predictions on validation set...")

y_pred = model.predict(X_val, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_val_classes = np.argmax(y_val, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_val_classes, y_pred_classes)
print("\n✓ Confusion Matrix:")
print(cm)

# Classification Report
print("\n✓ Classification Report:")
report = classification_report(y_val_classes, y_pred_classes, target_names=CLASS_NAMES)
print(report)

# Plot Confusion Matrix with CLEAR NUMBERS
print("\n📈 Plotting confusion matrix...")
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
            cbar_kws={'label': 'Count'},
            annot_kws={'size': 14, 'color': 'white', 'weight': 'bold'})
plt.title('Confusion Matrix - DenseNet-121', fontsize=16, fontweight='bold')
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.tight_layout()
plt.savefig('confusion_matrix_densenet.png', dpi=300, bbox_inches='tight')
print("✓ Confusion matrix saved as 'confusion_matrix_densenet.png'")
plt.show()

print("\n" + "="*70)
print("✅ ALL TRAINING AND EVALUATION COMPLETED SUCCESSFULLY!")
print("="*70)
print("\n📱 DenseNet-121 Benefits:")
print("  • Dense connectivity enables better gradient flow")
print("  • ~8M parameters for excellent accuracy")
print("  • Superior feature reuse and learning efficiency")
print("  • State-of-the-art accuracy for skin condition classification")
# Out:
# ======================================================================
# CONFUSION MATRIX & CLASSIFICATION REPORT
# ======================================================================
#
# 🔍 Generating predictions on validation set...
#
# ✓ Confusion Matrix:
# [[69  0  1  0  3  6]
#  [10 62  0  1  2  5]
#  [ 1  0 79  0  0  0]
#  [ 2  2  0 74  0  2]
#  [ 3  4  0  1 66  6]
#  [ 6  3  0  1  0 70]]
#
# ✓ Classification Report:
#               precision    recall  f1-score   support
#
#         acne       0.76      0.87      0.81        79
#       eczema       0.87      0.78      0.82        80
#    keratosis       0.99      0.99      0.99        80
#    carcinoma       0.96      0.93      0.94        80
#        milia       0.93      0.82      0.87        80
#      rosacea       0.79      0.88      0.83        80
#
#     accuracy                           0.88       479
#    macro avg       0.88      0.88      0.88       479
# weighted avg       0.88      0.88      0.88       479
#
#
# 📈 Plotting confusion matrix...
# ✓ Confusion matrix saved as 'confusion_matrix_densenet.png'
# ======================================================================
# ✅ ALL TRAINING AND EVALUATION COMPLETED SUCCESSFULLY!
# ======================================================================
#
# 📱 DenseNet-121 Benefits:
#   • Dense connectivity enables better gradient flow
#   • ~8M parameters for excellent accuracy
#   • Superior feature reuse and learning efficiency
#   • State-of-the-art accuracy for skin condition classification
